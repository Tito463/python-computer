# %%
Temperature=18

if Temperature>=30:
   print ("it is a hot day. stay hydrated!")
elif Temperature >20 and x <29:
   print ("it is a warm day. enjoy the weather!")
elif Temperature>10 and x<19:
   print ("it is cool day. wear a jacket!")
else:
    if Temperature<10 :
      print ("it is a cold day. stay warm!")
# Out:
# it is cool day. wear a jacket!

# %%
for number in range (1,20):
   if number % 3 == 0:
     print (number)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
