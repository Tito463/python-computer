# %% [markdown]
# # Contacts

# %%
People =["omar","Mahmoud"]
Phon_number=[12 , 15]

Phon_number.extend([11, 13, 10])
People.extend(["Ahmed","Ali","tito"])

print(People)
print(Phon_number)

print(People[-1],Phon_number[-1])
# Out:
# ['omar', 'Mahmoud', 'Ahmed', 'Ali', 'tito']
# [12, 15, 11, 13, 10]
# tito 10

# %% [markdown]
#  student grades

# %% [markdown]
# students grades

# %%
student1={"name":"tito","grades":[50,80,60]}
student2={"name":"Ahmed","grades":[90,80,70]}
student3={"name":"Ali","grades":[60,80,55]}
student4={"name":"Mahmoud","grades":[70,50,60]}
grades=student1.pop("grades")
student1["grades"]= 95
grades=student2.pop("grades")
student2["grades"]= 120
grades=student3.pop("grades")
student3["grades"]= 97.5
grades=student4.pop("grades")
student4["grades"]= 90
print(student1)
print(student2)
print(student3)
print(student4)
# Out:
# {'name': 'tito', 'grades': 95}
# {'name': 'Ahmed', 'grades': 120}
# {'name': 'Ali', 'grades': 97.5}
# {'name': 'Mahmoud', 'grades': 90}
