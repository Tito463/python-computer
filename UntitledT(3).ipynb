# %%
def is_prime(a):
   if a==2:
      return "First number even"
   elif a%2 == 0:
      return False
   else:
      return True
is_prime(2)
# Out:
# 'First number even'

# %%
def caicuiator(a,b):
    print(a+b)
caicuiator(a=5,b=10)
def c():
    print(a*b)
c()
def c():
    print(a/b)
c()
def c():
    print(b-a)
c()
# Out:
# 15
# 50
# 0.5
# 5
