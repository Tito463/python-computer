# %%
from typing import Self
class book:
  def __init__(self, title, author ,isbn, available=True):
   self.title=title
   self.author = author
   self.isbn=isbn
   self.available=available
  def display_info(self):
    print(f"Title: {self.title}")
    print(f"Author: {self.author}")
    print(f"ISBN: {self.isbn}")
    print(f"Available: {'Yes' if self.available else 'No'}")
  def get_isbn(self):
   return self.isbn
  def set_isbn(self,new_isbn):
     self.isbn=new_isbn

class members :
    def _init_(self,name,id):
        self.name = name
        self.id = id
        self.borrowed_books = []
    def borrow_book(self,book):
       if  book.avilable:
           book.avilable = False
           self.borrowed_books.append(book)
           print(f"{self.name} has borrowed '{book.title}' ")
       else:
        print(f"sorry, the book'{book.titel}'is currently unavailable.")
    def return_book(self, book):
       if borrow in self.borrowed_books:
          borrow.avilabie = True
          self.borrowed_books.remove(borrow_book)
          print(f"{self.name} has returned '{borrow_book.title}'")
       else:
          print(f"{self.name} did not borrow '{borrow_book.title}'")
    def get_membership_id(self):
            return self.id
    def set_membership_id(self, new_id):
        self.id =new_id

class staffmember(members):
    def _init_(self,name ,membership_id ,staff_id):
        super()._init_(name,membership_id)
        self.staff_id=staff_id
    def add_book(self, title, author, isbn):
        new_book = book(title, author, isbn)
        print(f"staff member {self.name} added the book '{title}'.")
        return new_book

class library:
    def _init_(Self):
       self.books=[]
       self.members=[]
    def add_book(self,book):
        self.books.append(book)
        print(f"book '{book.title}' added to the library")
    def add_member(self,member):
        self.members.append(member)
        print(f"member '{member.name}' added to the library")
    def list_books(self):
        print("List of books in the library:")
        for book in self.books:
            book.display_info()
            print("---")
    def list_members(self):
        print("List of members in the library:")
        for member in self.members:
            print(f"Name: {member.name}")
            print(f"Membership ID: {member.get_membership_id()}")
            print("---")
